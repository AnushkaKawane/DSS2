# %%
#Exp no.:7

# %%
#Aim:To perform the Simple Linear Regression For salary dataset

# %%
#Name:Anushka Prashant Kawane
#Roll No.:25
#Sec:C
#Subject:ET1
#Date:19-09-2025

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Victus\\OneDrive\\Desktop'

# %%
os.chdir('C:\\Users\\Victus\\OneDrive\\Desktop')

# %%
data=pd.read_csv("salary_data.csv")

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
data.shape
# Out:
# (30, 2)

# %%
data.size
# Out:
# 60

# %%
data.ndim
# Out:
# 2

# %%
data.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# Independent and Dependent Variable

# %%
x=data.drop('Salary',axis=1)

# %%
x.head()
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2

# %%
y=data.Salary

# %%
y.head()
# Out:
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# Name: Salary, dtype: float64

# %%
plt.plot(x,y)
plt.title("Line Chart")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=50,test_size=.3)

# %%
print(x_train.shape)
# Out:
# (21, 1)

# %%
x_test.shape
# Out:
# (9, 1)

# %% [markdown]
# Model Fitting

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
m = LR.coef_

# %%
print("Coefficient  :" , m)
# Out:
# Coefficient  : [9659.68375499]

# %%
c = LR.intercept_

# %%
print("Intercept : ", c)
# Out:
# Intercept :  24051.010161055106

# %% [markdown]
# y=mx+c

# %% [markdown]
# Evaluation Matrix

# %%
from sklearn import metrics

# %%
Accuracy = LR.score(x_test, y_test)
Accuracy
# Out:
# 0.9163676300745235

# %% [markdown]
# MAE

# %%
print(metrics.mean_absolute_error(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19420/1900466560.py in <module>
# ----> 1 print(metrics.mean_absolute_error(y_test,y_pred))
#
# NameError: name 'y_pred' is not defined

# %% [markdown]
# Prediction
