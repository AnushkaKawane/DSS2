# %%
#Aim:to perform operation on Basic of Data Frame

# %%
#Name:Anushka Prashant Kawane
#Roll No.:25
#Sec:C
#Subject:ET2

# %% [markdown]
# Creating Series

# %%
import pandas as pd

# %%
Name = ["Asish", "Sagar", "Shrikant", "Lovely", "Saurabh"]
Name
# Out:
# ['Asish', 'Sagar', 'Shrikant', 'Lovely', 'Saurabh']

# %%
Roll_list=pd.Series(Name,index=[1,2,3,4,5])
print(Roll_list)
# Out:
# 1       Asish
# 2       Sagar
# 3    Shrikant
# 4      Lovely
# 5     Saurabh
# dtype: object

# %% [markdown]
# Creating Data Frame

# %%
import pandas as pd

# %%
df=pd.DataFrame([[10,12,14,16],[11,18,15,21],[12,13,14,15]],
columns= ["CD","DBMS","DSS","CAO"])

# %%
df
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    12   14   16
# 1  11    18   15   21
# 2  12    13   14   15

# %%
df.shape
# Out:
# (3, 4)

# %%
df.size
# Out:
# 12

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# Adding Record (Row) to the data frame

# %%
df2=pd.DataFrame([[5,6,7,8]],
columns= ["CD","DBMS","DSS","CAO"])

# %%
df3=df.append(df2,ignore_index=True)

# %%
df3
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    12   14   16
# 1  11    18   15   21
# 2  12    13   14   15
# 3   5     6    7    8

# %% [markdown]
# Adding Attribute (Columns) name DM

# %%
df3["DM"]=[12,15,16,14]

# %%
df3
# Out:
#    CD  DBMS  DSS  CAO  DM
# 0  10    12   14   16  12
# 1  11    18   15   21  15
# 2  12    13   14   15  16
# 3   5     6    7    8  14

# %% [markdown]
# Deleting Record from  df3 dataframe

# %%
df4=df3.drop(index=[1])

# %%
df4
# Out:
#    CD  DBMS  DSS  CAO  DM
# 0  10    12   14   16  12
# 2  12    13   14   15  16
# 3   5     6    7    8  14

# %% [markdown]
# Deleting Attribute (Columns) from df3 dataframe

# %%
df5=df3.drop(columns=["DM"])

# %%
df5
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    12   14   16
# 1  11    18   15   21
# 2  12    13   14   15
# 3   5     6    7    8

# %%
print("Mean of DSS:", df5["DSS"].mean())
# Out:
# Mean of DSS: 12.5

# %%
print("Median of DSS:", df5["DSS"].median())
# Out:
# Median of DSS: 14.0

# %%
print("Mode of DSS:", df5["DSS"].mode())
# Out:
# Mode of DSS: 0    14
# dtype: int64

# %%
print("Max of DSS:", df5["DSS"].max())
# Out:
# Max of DSS: 15

# %%
print("Max of DSS:", df5["DSS"].min())
# Out:
# Max of DSS: 7
